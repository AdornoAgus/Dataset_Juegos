# %%
import pandas as pd

url1 = r"C:\Users\Admin\Desktop\coder\DATA SCIENCE\DatasetsGame\Video_Games.csv"
DATA = pd.read_csv(url1)

DATA.dropna(subset=['Year_of_Release'], inplace=True)
DATA['Critic_Score'].fillna(0, inplace=True)


DATA['Year_of_Release'] = pd.to_datetime(DATA['Year_of_Release'], format='%Y', errors='coerce')

df1 = DATA.copy()
df1 = df1[['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score']]

df1['Year_of_Release'] = df1['Year_of_Release'].dt.year

df1.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii             2006        Sports
# 1          Super Mario Bros.      NES             1985      Platform
# 2             Mario Kart Wii      Wii             2008        Racing
# 3          Wii Sports Resort      Wii             2009        Sports
# 4   Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                     Tetris       GB             1989        Puzzle
# 6      New Super Mario Bros.       DS             2006      Platform
# 7                   Wii Play      Wii             2006          Misc
# 8  New Super Mario Bros. Wii      Wii             2009      Platform
# 9                  Duck Hunt      NES             1984       Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# ...

# %%
url = "https://api.rawg.io/api/games"
url1 = r"C:\Users\Admin\Desktop\coder\DATA SCIENCE\DatasetsGame\Video_Games.csv"
params = {
    "key": "02d292424b944e6081c0c8bdcee20fbe",
    "dates": "2019-09-01,2023-07-12",
    "platforms":"1,2,3,4,5,6,7"
}

response = requests.get(url, params=params)
data = response.json()
indexed_data = {"data": data}

df_api = pd.DataFrame(indexed_data["data"])

#Exploracion de datos simple de la api
print("Datos de la API:")
print("Filas:", len(df_api))
print("Columnas:", len(df_api.columns))
print("Tipos de datos:")
print(df_api.dtypes)

#Exploracion de datos simple de la base de datos con la que trabajo
print("Datos existentes:")
print("Filas:", len(df1))
print("Columnas:", len(df1.columns))
print("Tipos de datos:")
print(df1.dtypes)

#Concatenacion de ambos y exploracion simple.
df_combined = pd.concat([df1, df_api], axis=1)
print("Datos combinados:")
print("Filas:", len(df_combined))
print("Columnas:", len(df_combined.columns))
print("Tipos de datos:")
print(df_combined.dtypes)
# Out:
# Datos de la API:
# Filas: 20
# Columnas: 5
# Tipos de datos:
# count              int64
# next              object
# previous          object
# results           object
# user_platforms      bool
# dtype: object
# Datos existentes:
# Filas: 16450
# Columnas: 11
# Tipos de datos:
# Name                object
# Platform            object
# Year_of_Release      int64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# dtype: object
# Datos combinados:
# Filas: 16450
# Columnas: 16
# Tipos de datos:
# Name                object
# Platform            object
# Year_of_Release      int64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# ...

# %%
df_api.head(20)
# Out:
#      count                                               next previous  \
# 0   347979  https://api.rawg.io/api/games?dates=2019-09-01...     None
# 1   347979  https://api.rawg.io/api/games?dates=2019-09-01...     None
# 2   347979  https://api.rawg.io/api/games?dates=2019-09-01...     None
# 3   347979  https://api.rawg.io/api/games?dates=2019-09-01...     None
# 4   347979  https://api.rawg.io/api/games?dates=2019-09-01...     None
# 5   347979  https://api.rawg.io/api/games?dates=2019-09-01...     None
# 6   347979  https://api.rawg.io/api/games?dates=2019-09-01...     None
# 7   347979  https://api.rawg.io/api/games?dates=2019-09-01...     None
# 8   347979  https://api.rawg.io/api/games?dates=2019-09-01...     None
# 9   347979  https://api.rawg.io/api/games?dates=2019-09-01...     None
# 10  347979  https://api.rawg.io/api/games?dates=2019-09-01...     None
# 11  347979  https://api.rawg.io/api/games?dates=2019-09-01...     None
# ...

# %%
df_api.count()
# Out:
# count             20
# next              20
# previous           0
# results           20
# user_platforms    20
# dtype: int64
